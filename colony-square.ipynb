# %%
# Import dependancies
from bs4 import BeautifulSoup
import requests
from splinter import Browser
from webdriver_manager.chrome import ChromeDriverManager
import pandas as pd
import pymongo

# %%
# Setup Mongo
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)
db = client.colony_square_db
collection = db.event_list

# %%
# Set up Chrome
executable_path = {'executable_path': ChromeDriverManager().install()}
browser = Browser('chrome', **executable_path, headless=False)
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 93.0.4577
# Get LATEST driver version for 93.0.4577
# Get LATEST driver version for 93.0.4577
# Trying to download new driver from https://chromedriver.storage.googleapis.com/93.0.4577.63/chromedriver_win32.zip
# Driver has been saved in cache [C:\Users\jerom\.wdm\drivers\chromedriver\win32\93.0.4577.63]

# %%
# Get Colony Square Events URL
url = "https://colonysquare.com/kiosk/events/"
response = requests.get(url)

# %%
# Parse response
soup = BeautifulSoup(response.text, 'html.parser')

# %%
# Create arrays for use in dataframe
event_name = []
event_desc = []
event_date = []
event_frequency = []
event_link = []

# %%
# Find first 10 event divs
# Scope of project is to use only first 10 events for each venue
results = soup.find_all('div', class_='event')[:10]

# %%
# Loop through results
for result in results:
    
    # Get event title
    event_title = result.find('div', class_='event-title').text
    
    # Retrieve event link
    # Then, go to event page and pull first paragraph to use as description
    event_page = result.find('a', class_='nav-link')['href']
    event_response = requests.get(f'https://colonysquare.com/{event_page}')
    soup2 = BeautifulSoup(event_response.text, 'html')
    ep_results = soup2.find('p').text
    
    # Get event date
    event_date_f = result.find('div', class_='event-date').text
    
    # Finds where 
    try:
        index = event_date_f.find("September")
        event_date_clean = event_date_f[index:] 
    
    except:
        event_date_clean = event_date_f
    
    # Get event occurance
    # Since we are only using the first 10 events, they are
    # Guaranteed to be within the month of September. 
    try:
        index2 = event_date_f.find("September")
        event_freq = event_date_f[:index]
        event_freq = event_freq.replace("from", "")
        
    except:
        event_freq = "Daily/One Day Event"
    
    # Append variables to arrays
    event_name.append(event_title)
    event_link.append(f'https://colonysquare.com/{event_page}')
    event_desc.append(ep_results)
    event_date.append(event_date_clean)
    event_frequency.append(event_freq)
    
    # Create post to Mongo
    post = {
        "event_name": event_title,
        "event_description": ep_results,
        "event_date": event_date_clean,
        "event_frequency": event_freq,
        "event_link": f'https://colonysquare.com/{event_page}'
    }
    
    # Post to Mongo
    collection.insert_one(post)

# %%
# Create df using created arrays
colony_square_df = pd.DataFrame({
    "event_name": event_name,
    "event_description": event_desc,
    "event_date": event_date,
    "event_frequency": event_frequency,
    "event_link": event_link
})

# %%
colony_square_df
# Out:
#                                  event_name  \
# 0                       National Yoga Month
# 1                    Game Day On The Square
# 2           What's Happening in Politan Row
# 3                Drag Bingo at Politan Row
# 4                       National Dance Week
# 5               Laughing Hour On The Square
# 6                               Colony Kids
# 7                        Yoga On The Square
# 8   CREW Atlanta Empowerment Speaker Series
# 9                      Movies On The Square
# 10                      National Yoga Month
# 11                   Game Day On The Square
# 12          What's Happening in Politan Row
# 13               Drag Bingo at Politan Row
# 14                      National Dance Week
# 15              Laughing Hour On The Square
# 16                              Colony Kids
# 17                       Yoga On The Square
# 18  CREW Atlanta Empowerment Speaker Series
# 19                     Movies On The Square
#
#                                     event_description  \
# 0   Throughout the month of September, we're encou...
# 1   It’s time to put on your game faces! Kick back...
# 2   Enjoy live music every week while you explore ...
# 3   Celebrate Sunday Funday every weekend at Polit...
# 4   Celebrate National Dance Week at Colony Square...
# 5   Laughing is good for the soul, so take a load ...
# 6   Enjoy Colony Kids the last Tuesday of the mont...
# 7   Discover your inner zen + take your practice t...
# 8   Colony Square is a viewing location for the Se...
# 9   Enjoy Movies On The Square the first Thursday ...
# 10  Throughout the month of September, we're encou...
# 11  It’s time to put on your game faces! Kick back...
# 12  Enjoy live music every week while you explore ...
# 13  Celebrate Sunday Funday every weekend at Polit...
# 14  Celebrate National Dance Week at Colony Square...
# 15  Laughing is good for the soul, so take a load ...
# 16  Enjoy Colony Kids the last Tuesday of the mont...
# 17  Discover your inner zen + take your practice t...
# 18  Colony Square is a viewing location for the Se...
# 19  Enjoy Movies On The Square the first Thursday ...
#
#                       event_date         event_frequency  \
# 0   September 11 to September 30                  Daily
# 1     September 11 to October 31                  Daily
# 2     September 11 to October 30  Mondays and Saturdays
# 3     September 12 to October 31                Sundays
# 4                   September 13                Monday,
# 5      September 13 to October 4                Mondays
# 6     September 14 to October 26               Tuesdays
# 7     September 15 to October 27             Wednesdays
# 8                   September 16              Thursday,
# 9      September 16 to October 7              Thursdays
# 10  September 11 to September 30                  Daily
# 11    September 11 to October 31                  Daily
# 12    September 11 to October 30  Mondays and Saturdays
# 13    September 12 to October 31                Sundays
# 14                  September 13                Monday,
# 15     September 13 to October 4                Mondays
# 16    September 14 to October 26               Tuesdays
# 17    September 15 to October 27             Wednesdays
# 18                  September 16              Thursday,
# 19     September 16 to October 7              Thursdays
#
#                                            event_link
# 0   https://colonysquare.com//kiosk/events/details...
# 1   https://colonysquare.com//kiosk/events/details...
# 2   https://colonysquare.com//kiosk/events/details...
# 3   https://colonysquare.com//kiosk/events/details...
# 4   https://colonysquare.com//kiosk/events/details...
# 5   https://colonysquare.com//kiosk/events/details...
# 6   https://colonysquare.com//kiosk/events/details...
# 7   https://colonysquare.com//kiosk/events/details...
# 8   https://colonysquare.com//kiosk/events/details...
# 9   https://colonysquare.com//kiosk/events/details...
# 10  https://colonysquare.com//kiosk/events/details...
# 11  https://colonysquare.com//kiosk/events/details...
# 12  https://colonysquare.com//kiosk/events/details...
# 13  https://colonysquare.com//kiosk/events/details...
# 14  https://colonysquare.com//kiosk/events/details...
# 15  https://colonysquare.com//kiosk/events/details...
# 16  https://colonysquare.com//kiosk/events/details...
# 17  https://colonysquare.com//kiosk/events/details...
# 18  https://colonysquare.com//kiosk/events/details...
# 19  https://colonysquare.com//kiosk/events/details...

# %%
colony_square_df.to_csv("colony_square.csv")

# %%
browser.quit()
